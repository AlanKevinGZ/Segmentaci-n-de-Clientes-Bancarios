# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./dataset/BankChurners.csv')

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.isna().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df = df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1)

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
sns.histplot(
    data=df,
    x="Total_Trans_Amt",
    hue="Attrition_Flag",
    kde=True,
    multiple="stack"
)

plt.show()

# %%
sns.histplot(
    data=df,
    x="Total_Trans_Ct",
    hue="Months_Inactive_12_mon",
    kde=True,
    multiple="stack"
)

plt.show()

# %%
df["Total_Trans_Ct"].corr(df["Months_Inactive_12_mon"])
# Out:
# np.float64(-0.042787039307753655)

# %%
sns.histplot(
    data=df,
    x="Total_Trans_Ct",
    hue="Attrition_Flag",
    kde=True,
    multiple="stack"
)


plt.show()

# %%
sns.histplot(data=df, x="Total_Relationship_Count", hue="Attrition_Flag", multiple="stack")
# Out:
# <Axes: xlabel='Total_Relationship_Count', ylabel='Count'>

# %%
sns.histplot(data=df, x="Months_on_book", hue="Attrition_Flag", multiple="stack")
# Out:
# <Axes: xlabel='Months_on_book', ylabel='Count'>

# %%
df.groupby("Total_Relationship_Count")["Attrition_Flag"].value_counts(normalize=True)
# Out:
# Total_Relationship_Count  Attrition_Flag
# 1                         Existing Customer    0.743956
#                           Attrited Customer    0.256044
# 2                         Existing Customer    0.721641
#                           Attrited Customer    0.278359
# 3                         Existing Customer    0.826464
#                           Attrited Customer    0.173536
# 4                         Existing Customer    0.882322
#                           Attrited Customer    0.117678
# 5                         Existing Customer    0.879958
#                           Attrited Customer    0.120042
# 6                         Existing Customer    0.894962
#                           Attrited Customer    0.105038
# Name: proportion, dtype: float64

# %%
df_clustering= df[["Total_Trans_Ct", "Total_Trans_Amt",'Total_Relationship_Count','Credit_Limit','Avg_Utilization_Ratio']]

# %%
df_clustering.head()
# Out:
#    Total_Trans_Ct  Total_Trans_Amt  Total_Relationship_Count  Credit_Limit  \
# 0              42             1144                         5       12691.0
# 1              33             1291                         6        8256.0
# 2              20             1887                         4        3418.0
# 3              20             1171                         3        3313.0
# 4              28              816                         5        4716.0
#
#    Avg_Utilization_Ratio
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000

# %%
from sklearn.preprocessing import StandardScaler # media = 0 y desviación estándar = 1

scaler = StandardScaler()

data_scaler = scaler.fit_transform(df_clustering)

df_escalado = pd.DataFrame(data_scaler, columns=df_clustering.columns)
# Out:
#    Total_Trans_Ct  Total_Trans_Amt  Total_Relationship_Count  Credit_Limit  \
# 0       -0.973895        -0.959707                  0.763943      0.446622
# 1       -1.357340        -0.916433                  1.407306     -0.041367
# 2       -1.911206        -0.740982                  0.120579     -0.573698
# 3       -1.911206        -0.951758                 -0.522785     -0.585251
# 4       -1.570365        -1.056263                  0.763943     -0.430877
#
#    Avg_Utilization_Ratio
# 0              -0.775882
# 1              -0.616276
# 2              -0.997155
# 3               1.759686
# 4              -0.997155

# %%
df_escalado.describe()
# Out:
#        Total_Trans_Ct  Total_Trans_Amt  Total_Relationship_Count  \
# count    1.012700e+04     1.012700e+04              1.012700e+04
# mean    -2.245222e-16    -8.980890e-17             -4.490445e-17
# std      1.000049e+00     1.000049e+00              1.000049e+00
# min     -2.337256e+00    -1.146344e+00             -1.809512e+00
# 25%     -8.460801e-01    -6.619405e-01             -5.227845e-01
# 50%      9.123036e-02    -1.486877e-01              1.205790e-01
# 75%      6.877007e-01     9.918090e-02              7.639426e-01
# max      3.158792e+00     4.144855e+00              1.407306e+00
#
#        Credit_Limit  Avg_Utilization_Ratio
# count  1.012700e+04           1.012700e+04
# mean   1.347133e-16          -7.296973e-17
# std    1.000049e+00           1.000049e+00
# min   -7.915266e-01          -9.971550e-01
# 25%   -6.686548e-01          -9.137243e-01
# 50%   -4.492525e-01          -3.587287e-01
# 75%    2.679862e-01           8.274384e-01
# ...

# %%
from sklearn.cluster import KMeans

inercias = []
for k in range(2,9):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_escalado)
    inercias.append(kmeans.inertia_)

plt.plot(range(2, 9), inercias, marker='o')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Inercia')
plt.title('Elbow Method')
plt.show()

# %%
kmeans_final = KMeans(n_clusters=4, random_state=42)
df["cluster"] = kmeans_final.fit_predict(df_escalado)

df["cluster"]
# Out:
# 0        2
# 1        2
# 2        1
# 3        0
# 4        2
#         ..
# 10122    3
# 10123    0
# 10124    2
# 10125    1
# 10126    2
# Name: cluster, Length: 10127, dtype: int32

# %%
df_gp_clouster=df.groupby("cluster")[["Total_Trans_Ct", "Total_Trans_Amt", "Total_Relationship_Count", "Credit_Limit", "Avg_Utilization_Ratio"]].mean()
df_gp_clouster
# Out:
#          Total_Trans_Ct  Total_Trans_Amt  Total_Relationship_Count  \
# cluster
# 0             63.490370      3571.458881                  4.221950
# 1             59.642601      3464.774066                  2.848779
# 2             55.886340      3008.503302                  4.975669
# 3            102.357322     12231.418410                  2.137238
#
#          Credit_Limit  Avg_Utilization_Ratio
# cluster
# 0         2759.950841               0.617950
# 1         5821.732040               0.120277
# 2        15020.557838               0.082686
# 3        15871.254393               0.158825

# %%
df.groupby("cluster")["Attrition_Flag"].value_counts(normalize=True)
# Out:
# cluster  Attrition_Flag
# 0        Existing Customer    0.917151
#          Attrited Customer    0.082849
# 1        Existing Customer    0.704023
#          Attrited Customer    0.295977
# 2        Existing Customer    0.841849
#          Attrited Customer    0.158151
# 3        Existing Customer    0.935565
#          Attrited Customer    0.064435
# Name: proportion, dtype: float64

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_escalado)

df["pca1"] = pca_result[:, 0]
df["pca2"] = pca_result[:, 1]

sns.scatterplot(data=df, x="pca1", y="pca2", hue="cluster", palette="tab10")
plt.title("Clusters visualizados con PCA")
plt.show()

# %%
df.groupby('cluster').size() * df_gp_clouster['Credit_Limit']
# Out:
# cluster
# 0     9027799.2
# 1    16207702.0
# 2    43214144.9
# 3    18966149.0
# dtype: float64

# %%
churn_pct = df.groupby('cluster')['Attrition_Flag'].value_counts(normalize=True).unstack()['Attrited Customer']

# %%
churn_pct
# Out:
# cluster
# 0    0.082849
# 1    0.295977
# 2    0.158151
# 3    0.064435
# Name: Attrited Customer, dtype: float64

# %%
clientes_riesgo = df.groupby('cluster').size() * churn_pct
clientes_riesgo
# Out:
# cluster
# 0    271.0
# 1    824.0
# 2    455.0
# 3     77.0
# dtype: float64

# %%
valor_riesgo = clientes_riesgo * df_gp_clouster['Total_Trans_Amt']
valor_riesgo
# Out:
# cluster
# 0    9.678654e+05
# 1    2.854974e+06
# 2    1.368869e+06
# 3    9.418192e+05
# dtype: float64

# %%
productos_faltantes = df_gp_clouster.loc[2, 'Total_Relationship_Count'] - df_gp_clouster.loc[3, 'Total_Relationship_Count']
clientes_cluster3 = df.groupby('cluster').size()[3]
ingreso_supuesto_por_producto = 750 

potencial_cross_sell = clientes_cluster3 * productos_faltantes * ingreso_supuesto_por_producto
potencial_cross_sell
# Out:
# np.float64(2543943.430656934)
